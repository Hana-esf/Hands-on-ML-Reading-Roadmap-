# %% [markdown]
# # Chapter 10 — Neural Nets with PyTorch
#
# *Your new default toolkit: tensors, autograd, torch.nn, and getting models into production.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - Tensors, GPU acceleration, and autograd
# - Building models with torch.nn.Module
# - Training loops: forward, loss, backward, optimizer.step()
# - TorchVision & TorchMetrics
# - Hyperparameter tuning with Optuna
# - The basics of saving/serving a trained model

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Rewrite Chapter 9's MLP for MNIST in raw PyTorch instead of Scikit-Learn
# **Exercise 2:** Move a training loop from CPU to GPU and benchmark the speedup
# **Exercise 3:** Use Optuna to search learning rate + hidden layer size over 20 trials

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Rewrite Chapter 9's MLP for MNIST in raw PyTorch instead of Scikit-Learn

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Move a training loop from CPU to GPU and benchmark the speedup

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Use Optuna to search learning rate + hidden layer size over 20 trials

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
