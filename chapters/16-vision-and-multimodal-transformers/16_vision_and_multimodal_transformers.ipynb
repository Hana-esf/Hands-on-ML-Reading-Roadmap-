# %% [markdown]
# # Chapter 16 — Vision and Multimodal Transformers
#
# *Transformers escape text: images, video, and models that connect the two.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - Vision Transformer (ViT) and patch embeddings
# - Efficient variants: DEiT, Swin, PVT
# - Self-supervised vision (DINO)
# - Multimodal models: CLIP, BLIP, Flamingo
# - Text-to-image generation basics (DALL·E)

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Run a pretrained ViT on your own images and inspect attention maps over patches
# **Exercise 2:** Use CLIP for zero-shot classification on a set of images with custom text labels
# **Exercise 3:** Compare a CNN vs. a ViT of similar size on the same small image dataset

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Run a pretrained ViT on your own images and inspect attention maps over patches

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Use CLIP for zero-shot classification on a set of images with custom text labels

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Compare a CNN vs. a ViT of similar size on the same small image dataset

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
