# %% [markdown]
# # Chapter 11 — Training Deep Neural Networks
#
# *Why deep nets are hard to train, and the toolbox that makes it work anyway.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - Vanishing/exploding gradients & better weight initialization
# - Batch Normalization
# - Faster optimizers: Momentum, RMSProp, Adam
# - Learning rate scheduling
# - Avoiding overfitting: Dropout, early stopping, weight regularization
# - Transfer learning

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Train the same deep MLP with SGD vs. Adam and compare convergence speed
# **Exercise 2:** Add Dropout and Batch Normalization to a model and compare validation curves
# **Exercise 3:** Fine-tune a pretrained model on a small dataset via transfer learning

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Train the same deep MLP with SGD vs. Adam and compare convergence speed

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Add Dropout and Batch Normalization to a model and compare validation curves

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Fine-tune a pretrained model on a small dataset via transfer learning

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
