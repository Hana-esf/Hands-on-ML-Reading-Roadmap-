# %% [markdown]
# # Chapter 14 — Natural Language Processing with RNNs and Attention
#
# *Text as sequences — and the attention mechanism that makes Transformers possible.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - Text preprocessing, tokenization, and word embeddings
# - Encoder-decoder architectures for sequence-to-sequence tasks (e.g., translation)
# - The bottleneck problem with fixed-size context vectors
# - The Attention mechanism as the fix
# - Sentiment analysis with RNNs

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Train a sentiment classifier using word embeddings + an RNN
# **Exercise 2:** Build a tiny encoder-decoder translator on a toy parallel dataset
# **Exercise 3:** Visualize attention weights as a heatmap over source and target words

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Train a sentiment classifier using word embeddings + an RNN

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Build a tiny encoder-decoder translator on a toy parallel dataset

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Visualize attention weights as a heatmap over source and target words

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
