# %% [markdown]
# # Chapter 17 — Speeding Up Transformers
#
# *Making the models from Ch.15-16 fast and cheap enough to actually deploy.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - KV-caching and speculative decoding
# - Sparse & approximate attention (Longformer, Reformer, Performer, etc.)
# - Multi-query / grouped-query / multi-head latent attention, FlashAttention
# - Mixture of Experts (MoE) for scaling
# - Parameter-efficient fine-tuning: LoRA and friends
# - Activation checkpointing, gradient accumulation, parallelism

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Benchmark generation speed with and without KV-caching on the same model
# **Exercise 2:** Fine-tune a model with LoRA and compare trainable-parameter count vs. full fine-tuning
# **Exercise 3:** Read one FlashAttention benchmark and summarize why it's faster despite doing the 'same' math

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Benchmark generation speed with and without KV-caching on the same model

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Fine-tune a model with LoRA and compare trainable-parameter count vs. full fine-tuning

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Read one FlashAttention benchmark and summarize why it's faster despite doing the 'same' math

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
