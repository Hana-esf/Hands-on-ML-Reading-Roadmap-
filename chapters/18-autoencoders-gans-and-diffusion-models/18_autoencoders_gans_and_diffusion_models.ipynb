# %% [markdown]
# # Chapter 18 — Autoencoders, GANs, and Diffusion Models
#
# *Teaching networks to compress data — and then to generate brand-new data.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - Autoencoders for dimensionality reduction & denoising
# - Variational Autoencoders (VAEs) and the latent space
# - Generative Adversarial Networks (GANs): generator vs. discriminator
# - Training instability & mode collapse in GANs
# - Diffusion models: forward noising, reverse denoising
# - Using pretrained diffusion models

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Train a simple autoencoder to denoise corrupted MNIST images
# **Exercise 2:** Train a GAN on a small dataset (e.g. Fashion-MNIST) and watch for mode collapse
# **Exercise 3:** Run a pretrained diffusion model and visualize a few denoising steps, not just the final image

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Train a simple autoencoder to denoise corrupted MNIST images

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Train a GAN on a small dataset (e.g. Fashion-MNIST) and watch for mode collapse

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Run a pretrained diffusion model and visualize a few denoising steps, not just the final image

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
