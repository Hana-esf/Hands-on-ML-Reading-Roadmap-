# %% [markdown]
# # Chapter 06 — Ensemble Learning and Random Forests
#
# *Why a crowd of mediocre models beats one great one.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - Voting classifiers (hard vs. soft voting)
# - Bagging and pasting
# - Random Forests & feature importance
# - Boosting: AdaBoost and Gradient Boosting
# - Stacking

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Compare a single Decision Tree vs. RandomForestClassifier on the same dataset/seed
# **Exercise 2:** Plot feature_importances_ from a Random Forest and sanity-check it against intuition
# **Exercise 3:** Train AdaBoost and GradientBoosting on the same data — compare training time & accuracy

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Compare a single Decision Tree vs. RandomForestClassifier on the same dataset/seed

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Plot feature_importances_ from a Random Forest and sanity-check it against intuition

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Train AdaBoost and GradientBoosting on the same data — compare training time & accuracy

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
