# %% [markdown]
# # Chapter 19 — Reinforcement Learning
#
# *Learning from trial, error, and reward instead of labeled examples.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - Markov Decision Processes, policies, and rewards
# - Policy Gradients
# - Actor-Critic methods, including PPO
# - Q-Learning and Deep Q-Networks
# - Training agents with Stable-Baselines3 (e.g. on Atari)

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Implement a basic Q-Learning agent on a simple grid-world (e.g. FrozenLake)
# **Exercise 2:** Train a PPO agent with Stable-Baselines3 on a Gym environment and plot the reward curve
# **Exercise 3:** Compare how sensitive your agent's training is to the reward function's shape

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Implement a basic Q-Learning agent on a simple grid-world (e.g. FrozenLake)

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Train a PPO agent with Stable-Baselines3 on a Gym environment and plot the reward curve

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Compare how sensitive your agent's training is to the reward function's shape

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
