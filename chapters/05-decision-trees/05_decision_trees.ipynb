# %% [markdown]
# # Chapter 05 — Decision Trees
#
# *A model you can literally read — until you let it grow too deep.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - CART algorithm & Gini impurity vs. entropy
# - How trees make predictions (white-box interpretability)
# - Regularization via max_depth, min_samples_leaf, etc.
# - Decision trees for regression
# - Instability: trees are sensitive to small data changes

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Train an unrestricted tree, then one with max_depth=3 — compare test accuracy
# **Exercise 2:** Export and visualize a tree with graphviz/plot_tree and manually trace one prediction
# **Exercise 3:** Rotate your training data 45° and retrain — watch how much the tree boundary changes

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Train an unrestricted tree, then one with max_depth=3 — compare test accuracy

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Export and visualize a tree with graphviz/plot_tree and manually trace one prediction

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Rotate your training data 45° and retrain — watch how much the tree boundary changes

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
