# %% [markdown]
# # Chapter 01 — The Machine Learning Landscape
#
# *What ML actually is, and the map of the territory before you touch any code.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - Supervised vs. unsupervised vs. reinforcement learning
# - Batch vs. online learning
# - Instance-based vs. model-based learning
# - Why generalization is the whole game: overfitting & underfitting
# - The 8 steps of a real ML project

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste, retype it, it sticks better).

# %%
# This chapter doesn't have any code examples, it's just a discussion of the concepts.

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:

# %% [markdown]
# ## Exercise 1
# ### How would you define machine learning?
# *This is my answer to this question. you can clear this cell and write your own answer if you want to.*
#
# Machine Learning is a field of study that teaches computers to learn from data without being explicitly programmed.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 2
# ### Can you name four types of applications where it shines?
# Here are four types of ML application:
# - detecting spam emails
# - predicting disease like tumor
# - credit card fraud detection
# - Recommending products to costumers

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 3
# ### What is a labeled training set?
# when the data in our dataset is tagged with specific labels, we call this labeled training set.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 4
# ### What are the two most common supervised tasks?
# the two most common supervised tasks are regression and classification.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 5
# ### Can you name four common unsupervised tasks?
# - clustring
# - anomaly detection
# - dimentionality reduction
# - assiciaition rule learning

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 6
# ### What type of algorithm would you use to allow a robot to walk in various unknown terrains?
# The best algorithm would be Reinforcement Learning since in this algorithm, we have an agent that can observe the environment and learn from its actions and based on the rewards or penalties that is gets, it can choose the best move to make.

# %% [markdown]
# ## Exercise 7
# ### What type of algorithm would you use to segment your customers into multiple groups?
# If the customers are titled or we knoe the title of the group, this problem is gonna be a supervised learning problem then we can use the classification algorithm to solve it, but if the customers or groups are not titled, it would be an unsupervised problem and we can use clustring.

# %% [markdown]
# ## Exercise 8
# ### Would you frame the problem of spam detection as a supervised learning problem or an unsupervised learning problem?
# since in spam detection problem, our data are labeled as spam so the algorithm can learn the patterm, it would be a supervised learning problem.

# %% [markdown]
# ## Exercise 9
# ## What is an online learning system?
# In online learning, the system will recieve the data in small chunks (mini batches) and process them step by step and not all at once. this way, we don't need complex system to run our model on it.

# %% [markdown]
# ## Exercise 10
# ### What is out-of-core learning?
# out-of-core algorithms can handls vast quantities of data that can not fit in computer's main memory so they get the data is small chuncks and use online learning to learn from those mini batches.

# %% [markdown]
# ## Exercise 11
# ### What type of algorithm relies on a similarity measure to make predictions?
# instance-based learning algorithms relise on similarity measures because they memorize the patterns in the example data they got and then compare the new unseen data with those examples using similarity measure to make predictions.

# %% [markdown]
# ## Exercise 12
# ### What is the difference between a model parameter and a model hyperparameter?
# A parameter is a default setting of the model that is being used during training so the optimal value of it be found. Hyperparameter is the variable that we define before the training starts.

# %% [markdown]
# ### Exercise 13
# ## What do model-based algorithms search for? What is the most common strategy they use to succeed? How do they make predictions?
# Model-based algorithms look for optimal values for parameters so that the model generalize well on new unseen data. These system will be trained by minimzing the cost function.

# %% [markdown]
# ### Exercise 14
# ## Can you name four of the main challenges in machine learning?
# - insufficient data
# - poor-quality data
# - non-representetive data
# - uninformative features
# - too complex model that overfit the data
# - too simple models that underfit the training data

# %% [markdown]
# ### Exercise 15
# ## If your model performs great on the training data but generalizes poorly to new instances, what is happening? Can you name three possible solutions?
# This happens when our model overfit the data which means it learns all the unique patterns in dataset too well, but it won't generalize well on new unseen data. In orser to fix this problem, we can add some constraint to our model which is also called regularization, or we can collect more data, or reducing noise in data.

# %% [markdown]
# ### Exercise 16
# ## What is a test set, and why would you want to use it?
# test set is a part of out dataset that we divide at the beginning and we use it to test the performace of our model. We shouldn't touch the test set until the very end of the training process becuause we want to see how our model works on unseen data.

# %% [markdown]
# ### Exercise 17
# ## What is the purpose of a validation set?
# validation set is a subset of test set that we use if for testing different parameters to find out what optimal value works the best and give us the better result.

# %% [markdown]
# ### Exercise 18
# ## What is the train-dev set, when do you need it, and how do you use it?
# The train-dev set is used when there is a risk of mismatch between the training data and the data used in the validation and test datasets.

# %% [markdown]
# ### Exercise 19
# ## What can go wrong if you tune hyperparameters using the test set?
# If we tune the hyperparameters using the test set, we're risking overfitting the test set which means our model's generalization will be optimistic and it would perform worst that we expect.

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
