# %% [markdown]
# # Chapter 07 — Dimensionality Reduction
#
# *Fighting the curse of dimensionality by throwing away the boring directions.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - The curse of dimensionality
# - Projection vs. Manifold learning
# - PCA (variance-preserving projection) and explained variance ratio
# - Kernel PCA
# - LLE and other manifold techniques

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Reduce MNIST to 2D with PCA and plot it colored by digit label
# **Exercise 2:** Find how many components are needed to preserve 95% of variance in a dataset of your choice
# **Exercise 3:** Compress then reconstruct images with PCA and visually inspect the information lost

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Reduce MNIST to 2D with PCA and plot it colored by digit label

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Find how many components are needed to preserve 95% of variance in a dataset of your choice

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Compress then reconstruct images with PCA and visually inspect the information lost

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
