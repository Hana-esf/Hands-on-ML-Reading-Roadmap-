# %% [markdown]
# # Chapter 12 — Deep Computer Vision with CNNs
#
# *Teaching networks to exploit the one thing images have that tabular data doesn't: spatial structure.*
#
# This notebook is your workspace for this chapter's hands-on practice. Read the corresponding chapter in the book first, follow along with its code examples in your own environment (or here), and then use the sections below to go further.

# %% [markdown]
# ## 🎯 Learning goals
#
# - Convolutional layers, filters, and feature maps
# - Pooling layers and translation invariance
# - Classic CNN architectures (LeNet, AlexNet, ResNet, etc.)
# - Object detection & semantic/instance segmentation basics
# - TorchVision pretrained models & transfer learning for vision

# %% [markdown]
# ## 1. Setup
#
# Install/import whatever this chapter needs. Uncomment as required.

# %%
# !pip install scikit-learn pandas numpy matplotlib torch torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
np.random.seed(42)

# %% [markdown]
# ## 2. Follow the book's examples
#
# Re-implement the chapter's core code here (don't just copy-paste — retype it, it sticks better).

# %%
# TODO: book's main code walkthrough

# %% [markdown]
# ## 3. Practice exercises
#
# Work through the ideas from this chapter's README, one cell per exercise:
#
# **Exercise 1:** Visualize the feature maps of the first conv layer on one input image
# **Exercise 2:** Fine-tune a pretrained ResNet on a small custom image dataset (transfer learning)
# **Exercise 3:** Compare a CNN vs. an MLP with the same parameter count on image classification accuracy

# %% [markdown]
# ### Exercise 1

# %%
# TODO: Visualize the feature maps of the first conv layer on one input image

# %% [markdown]
# ### Exercise 2

# %%
# TODO: Fine-tune a pretrained ResNet on a small custom image dataset (transfer learning)

# %% [markdown]
# ### Exercise 3

# %%
# TODO: Compare a CNN vs. an MLP with the same parameter count on image classification accuracy

# %% [markdown]
# ## 4. Reflection
#
# Answer briefly, in your own words (this is for you, not a grader):
#
# - What was the single most surprising or confusing idea in this chapter?
# - Where might this concept show up again later in the book, or in a real project?
# - What would you build if you had one extra day to explore this chapter's topic?

# %% [markdown]
# *Your reflection here...*
